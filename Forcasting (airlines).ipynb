# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
airlines=pd.read_excel("C:\\Users\\lenovo\\Downloads\\Airlines+Data.xlsx")

# %%
airlines
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306
#
# [96 rows x 2 columns]

# %% [markdown]
# # plotting the data

# %%
airlines.Passengers.plot()
# Out:
# <AxesSubplot:>

# %%
len(airlines)
# Out:
# 96

# %% [markdown]
# # Spliring train and test data

# %%
train=airlines.head(80)
test=airlines.tail(16)

# %%
train
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 75 2001-04-01         269
# 76 2001-05-01         270
# 77 2001-06-01         315
# 78 2001-07-01         364
# 79 2001-08-01         347
#
# [80 rows x 2 columns]

# %%
test
# Out:
#         Month  Passengers
# 80 2001-09-01         312
# 81 2001-10-01         274
# 82 2001-11-01         237
# 83 2001-12-01         278
# 84 2002-01-01         284
# 85 2002-02-01         277
# 86 2002-03-01         317
# 87 2002-04-01         313
# 88 2002-05-01         318
# 89 2002-06-01         374
# 90 2002-07-01         413
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306

# %% [markdown]
# # Moving average

# %%
a=range(3,15,3)
plt.figure(figsize=(24,7))
airlines.Passengers.plot(label="org")
for i in a:
    airlines["Passengers"].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best')

# %% [markdown]
# # Time series decomposition plot

# %%
decompose_ts_add=seasonal_decompose(airlines.Passengers,period=12)
decompose_ts_add.plot()
plt.show()

# %% [markdown]
# # ACF & PACF Plots

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(airlines.Passengers,lags=12)
tsa_plots.plot_pacf(airlines.Passengers,lags=12)
plt.show()

# %% [markdown]
# # Evaluation Metric MAPE

# %%
def MAPE(pred,org):
    temp=np.abs((pred-org)/org)*100
    return np.mean(temp)

# %%
weights=np.array([0.1,0.2,0.3,0.4])

# %% [markdown]
# # Weighted moving average

# %%
df=pd.DataFrame()
df['Passengers']=airlines.Passengers
df['WMA']=df['Passengers'].rolling(4).apply(lambda x:np.sum(weights*x))
df
# Out:
#     Passengers    WMA
# 0          112    NaN
# 1          118    NaN
# 2          132    NaN
# 3          129  126.0
# 4          121  125.3
# ..         ...    ...
# 91         405  392.5
# 92         355  383.5
# 93         306  351.2
# 94         271  311.7
# 95         306  300.4
#
# [96 rows x 2 columns]

# %% [markdown]
# # plotting weighted moving average

# %%
df.Passengers.plot(kind='line')
df.WMA.plot(kind='line')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# # simple Exponential Method

# %%
ses_model=SimpleExpSmoothing(train['Passengers']).fit(smoothing_level=0.2)
pred_ses=ses_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_ses,test.Passengers)
# Out:
# 11.375850554268187

# %% [markdown]
# # plotting for predictions for test data

# %%
plt.plot(pred_ses)
plt.plot(test.Passengers)

# %% [markdown]
# # whole data

# %%
plt.plot(ses_model.predict(start=airlines.index[0],end=airlines.index[-1]))
plt.plot(airlines.Passengers)

# %% [markdown]
# # find the best smoothing level value

# %%
acc_ses={}
for i in range(101):
    ses_model=SimpleExpSmoothing(train["Passengers"]).fit(smoothing_level=i/100)
    pred_ses=ses_model.predict(start=test.index[0],end=test.index[-1])
    acc_ses[MAPE(pred_ses,test.Passengers)]=i
    
print('{}:{}'.format(acc_ses[min(acc_ses.keys())],min(acc_ses.keys())))
# Out:
# 24:11.016377148078142

# %% [markdown]
# # Build a model with 0.23 as the smooting level values

# %%
ses_model=SimpleExpSmoothing(train["Passengers"]).fit(smoothing_level=0.24)
pred_ses=ses_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_ses,test.Passengers)
# Out:
# 11.016377148078142

# %% [markdown]
# # plotting the predictions on test data

# %%
plt.plot(pred_ses)
plt.plot(test.Passengers)

# %% [markdown]
# # Whole data

# %%
plt.plot(ses_model.predict(start=airlines.index[0],end=airlines.index[-1]))
plt.plot(airlines.Passengers)

# %% [markdown]
# # Build a model with holt method

# %%
holt_model=Holt(train["Passengers"]).fit(smoothing_level=0.8,smoothing_slope=0.3)
pred_holt=holt_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_holt,test.Passengers)
# Out:
# 59.933366922606936

# %% [markdown]
# # plotting the prediction on test data

# %%
plt.plot(pred_holt)
plt.plot(test.Passengers)

# %% [markdown]
# # Whole data

# %%
plt.plot(holt_model.predict(start=airlines.index[0],end=airlines.index[-1]))
plt.plot(airlines.Passengers)

# %% [markdown]
# # Find the best hyper parameters

# %%
accuracy={}
for i in range(0,101):
    for j in range(0,101):
        holt_model=Holt(train["Passengers"]).fit(smoothing_level=i/100,smoothing_slope=j/100)
        pred_holt=holt_model.predict(start=test.index[0],end=test.index[-1])
        accuracy[MAPE(pred_holt,test.Passengers)]=(i,j)

# %%
accuracy[min(accuracy.keys())]
# Out:
# (2, 63)

# %%
min(accuracy.keys())
# Out:
# 10.257527563336941

# %% [markdown]
# # Build a model with smoothing level=0.02 & smoothing sloe=0.63

# %%
holt_model=Holt(train["Passengers"]).fit(smoothing_level=0.02,smoothing_slope=0.63)
pred_holt=holt_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_holt,test.Passengers)
# Out:
# 10.257527563336941

# %% [markdown]
# # plotting the predictions on the test data

# %%
plt.plot(pred_holt)
plt.plot(test.Passengers)

# %% [markdown]
# # Whole Data

# %%
plt.plot(holt_model.predict(start=airlines.index[0],end=airlines.index[-1]))
plt.plot(airlines.Passengers)

# %% [markdown]
# # Build a model using holt winters method

# %% [markdown]
# # from the moving average plotted is earliers, it can be seen that the best seasonal period value is 12

# %%
hw_add_add = ExponentialSmoothing(train["Passengers"],seasonal='add',seasonal_periods=12).fit()
pred_hw_add=hw_add_add.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_hw_add,test.Passengers)
# Out:
# 6.528822465872382

# %% [markdown]
# # ploting the predictions in the test data

# %%
plt.plot(pred_hw_add)
plt.plot(test.Passengers)

# %% [markdown]
# # Whole data

# %%
plt.plot(hw_add_add.predict(start=airlines.index[0],end=airlines.index[-1]))
plt.plot(airlines.Passengers)

# %% [markdown]
# # find the best hyperparameter

# %%
params=['add','mul']
acc_hw={}
for i in params:
    for j in params:
        hw=ExponentialSmoothing(train["Passengers"],seasonal=i,trend=j,seasonal_periods=12).fit()
        pred_hw=hw.predict(start=test.index[0],end=test.index[-1])
        acc_hw[MAPE(pred_hw,test.Passengers)]=(i,j)

# %%
acc_hw[min(acc_hw.keys())]
# Out:
# ('mul', 'mul')

# %%
min(acc_hw.keys())
# Out:
# 1.8507445552553667

# %% [markdown]
# # Build a model with seasonal & trend to be multiplicative

# %%
hw=ExponentialSmoothing(train["Passengers"],seasonal='mul',trend='mul',seasonal_periods=12).fit()
pred_hw=hw.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_hw,test.Passengers)
# Out:
# 1.8507445552553667

# %% [markdown]
# # plotting the prediction on the test data

# %%
plt.plot(pred_hw)
plt.plot(test.Passengers)

# %%
plt.plot(hw.predict(start=airlines.index[0],end=airlines.index[-1]))
plt.plot(airlines.Passengers)

# %% [markdown]
# # conclusions

# %% [markdown]
# simple Exponential Smoothing = The best smoothing level value was found to be 0.24 the model built this value has an rms error value of 11.01

# %% [markdown]
# Holt's Model=The Best smoothing level value was found to be 0.02 & smoothing slope value is 0.63 the model built whit these parameters have an rms error value of 10.25

# %% [markdown]
# Holt-winter Method = The plitting both seasonal & trend to be multiplicative give the best results.the model built with these parameters gives an rms erroe of 1.85

# %% [markdown]
# so select the model is Holt Winters Model
