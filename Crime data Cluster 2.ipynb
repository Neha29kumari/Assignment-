# %%
import pandas as pd
import numpy as np
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import DBSCAN

# %%
df = pd.read_csv('C:\\Users\\lenovo\\Downloads\\crime_data.csv')
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
df.shape
# Out:
# (50, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  50 non-null     object
#  1   Murder      50 non-null     float64
#  2   Assault     50 non-null     int64
#  3   UrbanPop    50 non-null     int64
#  4   Rape        50 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.1+ KB

# %%
#Normalization function
def minmax_func(i):
    x= (i-i.min())/(i.max()- i.min())
    return(x)

# %%
#Normalized data from (considaring the numerical part of data)
df_norm = minmax_func(df.iloc[:,1:])

# %%
df_norm
# Out:
#       Murder   Assault  UrbanPop      Rape
# 0   0.746988  0.654110  0.440678  0.359173
# 1   0.554217  0.746575  0.271186  0.961240
# 2   0.439759  0.852740  0.813559  0.612403
# 3   0.481928  0.496575  0.305085  0.315245
# 4   0.493976  0.791096  1.000000  0.860465
# 5   0.427711  0.544521  0.779661  0.811370
# 6   0.150602  0.222603  0.762712  0.098191
# 7   0.307229  0.660959  0.677966  0.219638
# 8   0.879518  0.993151  0.813559  0.635659
# 9   1.000000  0.568493  0.474576  0.478036
# 10  0.271084  0.003425  0.864407  0.333333
# 11  0.108434  0.256849  0.372881  0.178295
# 12  0.578313  0.698630  0.864407  0.431525
# 13  0.385542  0.232877  0.559322  0.354005
# 14  0.084337  0.037671  0.423729  0.103359
# 15  0.313253  0.239726  0.576271  0.276486
# 16  0.536145  0.219178  0.338983  0.232558
# 17  0.879518  0.698630  0.576271  0.385013
# 18  0.078313  0.130137  0.322034  0.012920
# 19  0.632530  0.873288  0.593220  0.529716
# 20  0.216867  0.356164  0.898305  0.232558
# 21  0.680723  0.719178  0.711864  0.718346
# 22  0.114458  0.092466  0.576271  0.196382
# 23  0.921687  0.732877  0.203390  0.253230
# 24  0.493976  0.455479  0.644068  0.540052
# 25  0.313253  0.219178  0.355932  0.235142
# 26  0.210843  0.195205  0.508475  0.237726
# 27  0.686747  0.708904  0.830508  1.000000
# 28  0.078313  0.041096  0.406780  0.056848
# 29  0.397590  0.390411  0.966102  0.297158
# 30  0.638554  0.821918  0.644068  0.640827
# 31  0.620482  0.715753  0.915254  0.485788
# 32  0.734940  1.000000  0.220339  0.227390
# 33  0.000000  0.000000  0.203390  0.000000
# 34  0.391566  0.256849  0.728814  0.364341
# 35  0.349398  0.363014  0.610169  0.328165
# 36  0.246988  0.390411  0.593220  0.568475
# 37  0.331325  0.208904  0.677966  0.196382
# 38  0.156627  0.441781  0.932203  0.025840
# 39  0.819277  0.801370  0.271186  0.392765
# 40  0.180723  0.140411  0.220339  0.142119
# 41  0.746988  0.489726  0.457627  0.506460
# 42  0.716867  0.534247  0.813559  0.470284
# 43  0.144578  0.256849  0.813559  0.403101
# 44  0.084337  0.010274  0.000000  0.100775
# 45  0.463855  0.380137  0.525424  0.346253
# 46  0.192771  0.342466  0.694915  0.488372
# 47  0.295181  0.123288  0.118644  0.051680
# 48  0.108434  0.027397  0.576271  0.090439
# 49  0.361446  0.397260  0.474576  0.214470

# %%
#CREATE DENDROGRAM
denderogram = sch.dendrogram(sch.linkage(df_norm,method='complete'))

# %%
#crete Clusters
hc = AgglomerativeClustering(n_clusters=4,affinity = 'euclidean',linkage ='complete')

# %%
#Create a labels
y_hc = hc.fit_predict(df_norm)
y_hc
# Out:
# array([0, 0, 3, 1, 3, 3, 1, 1, 3, 0, 1, 2, 3, 1, 2, 1, 1, 0, 2, 3, 1, 3,
#        1, 0, 3, 2, 2, 3, 2, 1, 3, 3, 0, 2, 1, 1, 1, 1, 1, 0, 2, 0, 3, 1,
#        2, 1, 1, 2, 1, 1], dtype=int64)

# %%
clusters=pd.DataFrame(y_hc,columns=['Clusters'])
clusters
# Out:
#     Clusters
# 0          0
# 1          0
# 2          3
# 3          1
# 4          3
# 5          3
# 6          1
# 7          1
# 8          3
# 9          0
# 10         1
# 11         2
# 12         3
# 13         1
# 14         2
# 15         1
# 16         1
# 17         0
# 18         2
# 19         3
# 20         1
# 21         3
# 22         1
# 23         0
# 24         3
# 25         2
# 26         2
# 27         3
# 28         2
# 29         1
# 30         3
# 31         3
# 32         0
# 33         2
# 34         1
# 35         1
# 36         1
# 37         1
# 38         1
# 39         0
# 40         2
# 41         0
# 42         3
# 43         1
# 44         2
# 45         1
# 46         1
# 47         2
# 48         1
# 49         1

# %%
df.value_counts()
# Out:
# Unnamed: 0      Murder  Assault  UrbanPop  Rape
# Alabama         13.2    236      58        21.2    1
# Pennsylvania    6.3     106      72        14.9    1
# Nevada          12.2    252      81        46.0    1
# New Hampshire   2.1     57       56        9.5     1
# New Jersey      7.4     159      89        18.8    1
# New Mexico      11.4    285      70        32.1    1
# New York        11.1    254      86        26.1    1
# North Carolina  13.0    337      45        16.1    1
# North Dakota    0.8     45       44        7.3     1
# Ohio            7.3     120      75        21.4    1
# Oklahoma        6.6     151      68        20.0    1
# Oregon          4.9     159      67        29.3    1
# Rhode Island    3.4     174      87        8.3     1
# Alaska          10.0    263      48        44.5    1
# South Carolina  14.4    279      48        22.5    1
# South Dakota    3.8     86       45        12.8    1
# Tennessee       13.2    188      59        26.9    1
# Texas           12.7    201      80        25.5    1
# Utah            3.2     120      80        22.9    1
# Vermont         2.2     48       32        11.2    1
# Virginia        8.5     156      63        20.7    1
# Washington      4.0     145      73        26.2    1
# West Virginia   5.7     81       39        9.3     1
# Wisconsin       2.6     53       66        10.8    1
# Nebraska        4.3     102      62        16.5    1
# Montana         6.0     109      53        16.4    1
# Missouri        9.0     178      70        28.2    1
# Mississippi     16.1    259      44        17.1    1
# Arizona         8.1     294      80        31.0    1
# Arkansas        8.8     190      50        19.5    1
# California      9.0     276      91        40.6    1
# Colorado        7.9     204      78        38.7    1
# Connecticut     3.3     110      77        11.1    1
# Delaware        5.9     238      72        15.8    1
# Florida         15.4    335      80        31.9    1
# Georgia         17.4    211      60        25.8    1
# Hawaii          5.3     46       83        20.2    1
# Idaho           2.6     120      54        14.2    1
# Illinois        10.4    249      83        24.0    1
# Indiana         7.2     113      65        21.0    1
# Iowa            2.2     56       57        11.3    1
# Kansas          6.0     115      66        18.0    1
# Kentucky        9.7     109      52        16.3    1
# Louisiana       15.4    249      66        22.2    1
# Maine           2.1     83       51        7.8     1
# Maryland        11.3    300      67        27.8    1
# Massachusetts   4.4     149      85        16.3    1
# Michigan        12.1    255      74        35.1    1
# Minnesota       2.7     72       66        14.9    1
# Wyoming         6.8     161      60        15.6    1
# dtype: int64

# %%
df['h_clusterid'] = y_hc
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  h_clusterid
# 0          Alabama    13.2      236        58  21.2            0
# 1           Alaska    10.0      263        48  44.5            0
# 2          Arizona     8.1      294        80  31.0            3
# 3         Arkansas     8.8      190        50  19.5            1
# 4       California     9.0      276        91  40.6            3
# 5         Colorado     7.9      204        78  38.7            3
# 6      Connecticut     3.3      110        77  11.1            1
# 7         Delaware     5.9      238        72  15.8            1
# 8          Florida    15.4      335        80  31.9            3
# 9          Georgia    17.4      211        60  25.8            0
# 10          Hawaii     5.3       46        83  20.2            1
# 11           Idaho     2.6      120        54  14.2            2
# 12        Illinois    10.4      249        83  24.0            3
# 13         Indiana     7.2      113        65  21.0            1
# 14            Iowa     2.2       56        57  11.3            2
# 15          Kansas     6.0      115        66  18.0            1
# 16        Kentucky     9.7      109        52  16.3            1
# 17       Louisiana    15.4      249        66  22.2            0
# 18           Maine     2.1       83        51   7.8            2
# 19        Maryland    11.3      300        67  27.8            3
# 20   Massachusetts     4.4      149        85  16.3            1
# 21        Michigan    12.1      255        74  35.1            3
# 22       Minnesota     2.7       72        66  14.9            1
# 23     Mississippi    16.1      259        44  17.1            0
# 24        Missouri     9.0      178        70  28.2            3
# 25         Montana     6.0      109        53  16.4            2
# 26        Nebraska     4.3      102        62  16.5            2
# 27          Nevada    12.2      252        81  46.0            3
# 28   New Hampshire     2.1       57        56   9.5            2
# 29      New Jersey     7.4      159        89  18.8            1
# 30      New Mexico    11.4      285        70  32.1            3
# 31        New York    11.1      254        86  26.1            3
# 32  North Carolina    13.0      337        45  16.1            0
# 33    North Dakota     0.8       45        44   7.3            2
# 34            Ohio     7.3      120        75  21.4            1
# 35        Oklahoma     6.6      151        68  20.0            1
# 36          Oregon     4.9      159        67  29.3            1
# 37    Pennsylvania     6.3      106        72  14.9            1
# 38    Rhode Island     3.4      174        87   8.3            1
# 39  South Carolina    14.4      279        48  22.5            0
# 40    South Dakota     3.8       86        45  12.8            2
# 41       Tennessee    13.2      188        59  26.9            0
# 42           Texas    12.7      201        80  25.5            3
# 43            Utah     3.2      120        80  22.9            1
# 44         Vermont     2.2       48        32  11.2            2
# 45        Virginia     8.5      156        63  20.7            1
# 46      Washington     4.0      145        73  26.2            1
# 47   West Virginia     5.7       81        39   9.3            2
# 48       Wisconsin     2.6       53        66  10.8            1
# 49         Wyoming     6.8      161        60  15.6            1

# %%
df.groupby('h_clusterid').mean()
# Out:
#                 Murder     Assault   UrbanPop     Rape
# h_clusterid
# 0            14.087500  252.750000  53.500000  24.5375
# 1             5.715000  132.300000  70.800000  18.1000
# 2             3.180000   78.700000  49.300000  11.6300
# 3            10.883333  256.916667  78.333333  32.2500

# %% [markdown]
# # Kmeans

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df.iloc[:,1:])

# %%
scaled_df
# Out:
# array([[ 1.25517927,  0.79078716, -0.52619514, -0.00345116, -1.48365074],
#        [ 0.51301858,  1.11805959, -1.22406668,  2.50942392, -1.48365074],
#        [ 0.07236067,  1.49381682,  1.00912225,  1.05346626,  1.4446073 ],
#        [ 0.23470832,  0.23321191, -1.08449238, -0.18679398, -0.50756473],
#        [ 0.28109336,  1.2756352 ,  1.77678094,  2.08881393,  1.4446073 ],
#        [ 0.02597562,  0.40290872,  0.86954794,  1.88390137,  1.4446073 ],
#        [-1.04088037, -0.73648418,  0.79976079, -1.09272319, -0.50756473],
#        [-0.43787481,  0.81502956,  0.45082502, -0.58583422, -0.50756473],
#        [ 1.76541475,  1.99078607,  1.00912225,  1.1505301 ,  1.4446073 ],
#        [ 2.22926518,  0.48775713, -0.38662083,  0.49265293, -1.48365074],
#        [-0.57702994, -1.51224105,  1.21848371, -0.11129987, -0.50756473],
#        [-1.20322802, -0.61527217, -0.80534376, -0.75839217,  0.46852129],
#        [ 0.60578867,  0.94836277,  1.21848371,  0.29852525,  1.4446073 ],
#        [-0.13637203, -0.70012057, -0.03768506, -0.0250209 , -0.50756473],
#        [-1.29599811, -1.39102904, -0.5959823 , -1.07115345,  0.46852129],
#        [-0.41468229, -0.67587817,  0.03210209, -0.34856705, -0.50756473],
#        [ 0.44344101, -0.74860538, -0.94491807, -0.53190987, -0.50756473],
#        [ 1.76541475,  0.94836277,  0.03210209,  0.10439756, -1.48365074],
#        [-1.31919063, -1.06375661, -1.01470522, -1.44862395,  0.46852129],
#        [ 0.81452136,  1.56654403,  0.10188925,  0.70835037,  1.4446073 ],
#        [-0.78576263, -0.26375734,  1.35805802, -0.53190987, -0.50756473],
#        [ 1.00006153,  1.02108998,  0.59039932,  1.49564599,  1.4446073 ],
#        [-1.1800355 , -1.19708982,  0.03210209, -0.68289807, -0.50756473],
#        [ 1.9277624 ,  1.06957478, -1.5032153 , -0.44563089, -1.48365074],
#        [ 0.28109336,  0.0877575 ,  0.31125071,  0.75148985,  1.4446073 ],
#        [-0.41468229, -0.74860538, -0.87513091, -0.521125  ,  0.46852129],
#        [-0.80895515, -0.83345379, -0.24704653, -0.51034012,  0.46852129],
#        [ 1.02325405,  0.98472638,  1.0789094 ,  2.671197  ,  1.4446073 ],
#        [-1.31919063, -1.37890783, -0.66576945, -1.26528114,  0.46852129],
#        [-0.08998698, -0.14254532,  1.63720664, -0.26228808, -0.50756473],
#        [ 0.83771388,  1.38472601,  0.31125071,  1.17209984,  1.4446073 ],
#        [ 0.76813632,  1.00896878,  1.42784517,  0.52500755,  1.4446073 ],
#        [ 1.20879423,  2.01502847, -1.43342815, -0.55347961, -1.48365074],
#        [-1.62069341, -1.52436225, -1.5032153 , -1.50254831,  0.46852129],
#        [-0.11317951, -0.61527217,  0.66018648,  0.01811858, -0.50756473],
#        [-0.27552716, -0.23951493,  0.1716764 , -0.13286962, -0.50756473],
#        [-0.66980002, -0.14254532,  0.10188925,  0.87012344, -0.50756473],
#        [-0.34510472, -0.78496898,  0.45082502, -0.68289807, -0.50756473],
#        [-1.01768785,  0.03927269,  1.49763233, -1.39469959, -0.50756473],
#        [ 1.53348953,  1.3119988 , -1.22406668,  0.13675217, -1.48365074],
#        [-0.92491776, -1.027393  , -1.43342815, -0.90938037,  0.46852129],
#        [ 1.25517927,  0.20896951, -0.45640799,  0.61128652, -1.48365074],
#        [ 1.13921666,  0.36654512,  1.00912225,  0.46029832,  1.4446073 ],
#        [-1.06407289, -0.61527217,  1.00912225,  0.17989166, -0.50756473],
#        [-1.29599811, -1.48799864, -2.34066115, -1.08193832,  0.46852129],
#        [ 0.16513075, -0.17890893, -0.17725937, -0.05737552, -0.50756473],
#        [-0.87853272, -0.31224214,  0.52061217,  0.53579242, -0.50756473],
#        [-0.48425985, -1.08799901, -1.85215107, -1.28685088,  0.46852129],
#        [-1.20322802, -1.42739264,  0.03210209, -1.1250778 , -0.50756473],
#        [-0.22914211, -0.11830292, -0.38662083, -0.60740397, -0.50756473]])

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range(1,11):
    km = KMeans(n_clusters=i)
    km.fit(scaled_df)
    wcss.append( km.inertia_)
    
plt.plot(range(1,11),wcss)
plt.title('elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
wcss
# Out:
# [250.00000000000003,
#  152.47179575919472,
#  90.91274995389853,
#  60.90186400248542,
#  52.234207930759084,
#  46.98834507326145,
#  41.64060056689783,
#  39.408070509504725,
#  33.00458917610877,
#  29.787693420244757]

# %%
#swlwction 4 clusters from above scree plot
model =KMeans(n_clusters=4)
model.fit(df_norm)
model.labels_
# Out:
# array([3, 2, 2, 3, 2, 2, 0, 0, 2, 3, 0, 1, 2, 0, 1, 0, 1, 3, 1, 2, 0, 2,
#        1, 3, 0, 1, 1, 2, 1, 0, 2, 2, 3, 1, 0, 0, 0, 0, 0, 3, 1, 3, 2, 0,
#        1, 0, 0, 1, 1, 0])

# %%
x= df.iloc[:,:].values
km = KMeans(n_clusters=4)
y_means = km.fit_predict(scaled_df)

# %%
y_means
# Out:
# array([2, 2, 1, 2, 1, 1, 0, 0, 1, 2, 0, 3, 1, 0, 3, 0, 0, 2, 3, 1, 0, 1,
#        0, 2, 1, 3, 3, 1, 3, 0, 1, 1, 2, 3, 0, 0, 0, 0, 0, 2, 3, 2, 1, 0,
#        3, 0, 0, 3, 3, 0])

# %%
x[y_means==0,0]
# Out:
# array(['Connecticut', 'Delaware', 'Hawaii', 'Indiana', 'Kansas',
#        'Kentucky', 'Massachusetts', 'Minnesota', 'New Jersey', 'Ohio',
#        'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'Utah',
#        'Virginia', 'Washington', 'Wyoming'], dtype=object)

# %%
plt.scatter(x[y_means==0,0],x[y_means==0,1],color="Blue")
plt.scatter(x[y_means==1,0],x[y_means==1,1],color="Red")
plt.scatter(x[y_means==2,0],x[y_means==2,2],color="Green")
plt.scatter(x[y_means==3,0],x[y_means==3,3],color="Black")

# %% [markdown]
# # DB-Scan

# %%
df
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape  h_clusterid
# 0          Alabama    13.2      236        58  21.2            0
# 1           Alaska    10.0      263        48  44.5            0
# 2          Arizona     8.1      294        80  31.0            3
# 3         Arkansas     8.8      190        50  19.5            1
# 4       California     9.0      276        91  40.6            3
# 5         Colorado     7.9      204        78  38.7            3
# 6      Connecticut     3.3      110        77  11.1            1
# 7         Delaware     5.9      238        72  15.8            1
# 8          Florida    15.4      335        80  31.9            3
# 9          Georgia    17.4      211        60  25.8            0
# 10          Hawaii     5.3       46        83  20.2            1
# 11           Idaho     2.6      120        54  14.2            2
# 12        Illinois    10.4      249        83  24.0            3
# 13         Indiana     7.2      113        65  21.0            1
# 14            Iowa     2.2       56        57  11.3            2
# 15          Kansas     6.0      115        66  18.0            1
# 16        Kentucky     9.7      109        52  16.3            1
# 17       Louisiana    15.4      249        66  22.2            0
# 18           Maine     2.1       83        51   7.8            2
# 19        Maryland    11.3      300        67  27.8            3
# 20   Massachusetts     4.4      149        85  16.3            1
# 21        Michigan    12.1      255        74  35.1            3
# 22       Minnesota     2.7       72        66  14.9            1
# 23     Mississippi    16.1      259        44  17.1            0
# 24        Missouri     9.0      178        70  28.2            3
# 25         Montana     6.0      109        53  16.4            2
# 26        Nebraska     4.3      102        62  16.5            2
# 27          Nevada    12.2      252        81  46.0            3
# 28   New Hampshire     2.1       57        56   9.5            2
# 29      New Jersey     7.4      159        89  18.8            1
# 30      New Mexico    11.4      285        70  32.1            3
# 31        New York    11.1      254        86  26.1            3
# 32  North Carolina    13.0      337        45  16.1            0
# 33    North Dakota     0.8       45        44   7.3            2
# 34            Ohio     7.3      120        75  21.4            1
# 35        Oklahoma     6.6      151        68  20.0            1
# 36          Oregon     4.9      159        67  29.3            1
# 37    Pennsylvania     6.3      106        72  14.9            1
# 38    Rhode Island     3.4      174        87   8.3            1
# 39  South Carolina    14.4      279        48  22.5            0
# 40    South Dakota     3.8       86        45  12.8            2
# 41       Tennessee    13.2      188        59  26.9            0
# 42           Texas    12.7      201        80  25.5            3
# 43            Utah     3.2      120        80  22.9            1
# 44         Vermont     2.2       48        32  11.2            2
# 45        Virginia     8.5      156        63  20.7            1
# 46      Washington     4.0      145        73  26.2            1
# 47   West Virginia     5.7       81        39   9.3            2
# 48       Wisconsin     2.6       53        66  10.8            1
# 49         Wyoming     6.8      161        60  15.6            1

# %%
df.drop(['Unnamed: 0','Assault'],axis=1,inplace=True)

# %%
df
# Out:
#     Murder  UrbanPop  Rape  h_clusterid
# 0     13.2        58  21.2            0
# 1     10.0        48  44.5            0
# 2      8.1        80  31.0            3
# 3      8.8        50  19.5            1
# 4      9.0        91  40.6            3
# 5      7.9        78  38.7            3
# 6      3.3        77  11.1            1
# 7      5.9        72  15.8            1
# 8     15.4        80  31.9            3
# 9     17.4        60  25.8            0
# 10     5.3        83  20.2            1
# 11     2.6        54  14.2            2
# 12    10.4        83  24.0            3
# 13     7.2        65  21.0            1
# 14     2.2        57  11.3            2
# 15     6.0        66  18.0            1
# 16     9.7        52  16.3            1
# 17    15.4        66  22.2            0
# 18     2.1        51   7.8            2
# 19    11.3        67  27.8            3
# 20     4.4        85  16.3            1
# 21    12.1        74  35.1            3
# 22     2.7        66  14.9            1
# 23    16.1        44  17.1            0
# 24     9.0        70  28.2            3
# 25     6.0        53  16.4            2
# 26     4.3        62  16.5            2
# 27    12.2        81  46.0            3
# 28     2.1        56   9.5            2
# 29     7.4        89  18.8            1
# 30    11.4        70  32.1            3
# 31    11.1        86  26.1            3
# 32    13.0        45  16.1            0
# 33     0.8        44   7.3            2
# 34     7.3        75  21.4            1
# 35     6.6        68  20.0            1
# 36     4.9        67  29.3            1
# 37     6.3        72  14.9            1
# 38     3.4        87   8.3            1
# 39    14.4        48  22.5            0
# 40     3.8        45  12.8            2
# 41    13.2        59  26.9            0
# 42    12.7        80  25.5            3
# 43     3.2        80  22.9            1
# 44     2.2        32  11.2            2
# 45     8.5        63  20.7            1
# 46     4.0        73  26.2            1
# 47     5.7        39   9.3            2
# 48     2.6        66  10.8            1
# 49     6.8        60  15.6            1

# %%
array_DBSCAN= df.values

# %%
array_DBSCAN
# Out:
# array([[13.2, 58. , 21.2,  0. ],
#        [10. , 48. , 44.5,  0. ],
#        [ 8.1, 80. , 31. ,  3. ],
#        [ 8.8, 50. , 19.5,  1. ],
#        [ 9. , 91. , 40.6,  3. ],
#        [ 7.9, 78. , 38.7,  3. ],
#        [ 3.3, 77. , 11.1,  1. ],
#        [ 5.9, 72. , 15.8,  1. ],
#        [15.4, 80. , 31.9,  3. ],
#        [17.4, 60. , 25.8,  0. ],
#        [ 5.3, 83. , 20.2,  1. ],
#        [ 2.6, 54. , 14.2,  2. ],
#        [10.4, 83. , 24. ,  3. ],
#        [ 7.2, 65. , 21. ,  1. ],
#        [ 2.2, 57. , 11.3,  2. ],
#        [ 6. , 66. , 18. ,  1. ],
#        [ 9.7, 52. , 16.3,  1. ],
#        [15.4, 66. , 22.2,  0. ],
#        [ 2.1, 51. ,  7.8,  2. ],
#        [11.3, 67. , 27.8,  3. ],
#        [ 4.4, 85. , 16.3,  1. ],
#        [12.1, 74. , 35.1,  3. ],
#        [ 2.7, 66. , 14.9,  1. ],
#        [16.1, 44. , 17.1,  0. ],
#        [ 9. , 70. , 28.2,  3. ],
#        [ 6. , 53. , 16.4,  2. ],
#        [ 4.3, 62. , 16.5,  2. ],
#        [12.2, 81. , 46. ,  3. ],
#        [ 2.1, 56. ,  9.5,  2. ],
#        [ 7.4, 89. , 18.8,  1. ],
#        [11.4, 70. , 32.1,  3. ],
#        [11.1, 86. , 26.1,  3. ],
#        [13. , 45. , 16.1,  0. ],
#        [ 0.8, 44. ,  7.3,  2. ],
#        [ 7.3, 75. , 21.4,  1. ],
#        [ 6.6, 68. , 20. ,  1. ],
#        [ 4.9, 67. , 29.3,  1. ],
#        [ 6.3, 72. , 14.9,  1. ],
#        [ 3.4, 87. ,  8.3,  1. ],
#        [14.4, 48. , 22.5,  0. ],
#        [ 3.8, 45. , 12.8,  2. ],
#        [13.2, 59. , 26.9,  0. ],
#        [12.7, 80. , 25.5,  3. ],
#        [ 3.2, 80. , 22.9,  1. ],
#        [ 2.2, 32. , 11.2,  2. ],
#        [ 8.5, 63. , 20.7,  1. ],
#        [ 4. , 73. , 26.2,  1. ],
#        [ 5.7, 39. ,  9.3,  2. ],
#        [ 2.6, 66. , 10.8,  1. ],
#        [ 6.8, 60. , 15.6,  1. ]])

# %% [raw]
# stscaler = StandardScaler().fit(array)
# x = stscaler.transform(array_DBSCAN)

# %%
x
# Out:
# array([['Alabama', 13.2, 236, 58, 21.2, 0],
#        ['Alaska', 10.0, 263, 48, 44.5, 0],
#        ['Arizona', 8.1, 294, 80, 31.0, 3],
#        ['Arkansas', 8.8, 190, 50, 19.5, 1],
#        ['California', 9.0, 276, 91, 40.6, 3],
#        ['Colorado', 7.9, 204, 78, 38.7, 3],
#        ['Connecticut', 3.3, 110, 77, 11.1, 1],
#        ['Delaware', 5.9, 238, 72, 15.8, 1],
#        ['Florida', 15.4, 335, 80, 31.9, 3],
#        ['Georgia', 17.4, 211, 60, 25.8, 0],
#        ['Hawaii', 5.3, 46, 83, 20.2, 1],
#        ['Idaho', 2.6, 120, 54, 14.2, 2],
#        ['Illinois', 10.4, 249, 83, 24.0, 3],
#        ['Indiana', 7.2, 113, 65, 21.0, 1],
#        ['Iowa', 2.2, 56, 57, 11.3, 2],
#        ['Kansas', 6.0, 115, 66, 18.0, 1],
#        ['Kentucky', 9.7, 109, 52, 16.3, 1],
#        ['Louisiana', 15.4, 249, 66, 22.2, 0],
#        ['Maine', 2.1, 83, 51, 7.8, 2],
#        ['Maryland', 11.3, 300, 67, 27.8, 3],
#        ['Massachusetts', 4.4, 149, 85, 16.3, 1],
#        ['Michigan', 12.1, 255, 74, 35.1, 3],
#        ['Minnesota', 2.7, 72, 66, 14.9, 1],
#        ['Mississippi', 16.1, 259, 44, 17.1, 0],
#        ['Missouri', 9.0, 178, 70, 28.2, 3],
#        ['Montana', 6.0, 109, 53, 16.4, 2],
#        ['Nebraska', 4.3, 102, 62, 16.5, 2],
#        ['Nevada', 12.2, 252, 81, 46.0, 3],
#        ['New Hampshire', 2.1, 57, 56, 9.5, 2],
#        ['New Jersey', 7.4, 159, 89, 18.8, 1],
#        ['New Mexico', 11.4, 285, 70, 32.1, 3],
#        ['New York', 11.1, 254, 86, 26.1, 3],
#        ['North Carolina', 13.0, 337, 45, 16.1, 0],
#        ['North Dakota', 0.8, 45, 44, 7.3, 2],
#        ['Ohio', 7.3, 120, 75, 21.4, 1],
#        ['Oklahoma', 6.6, 151, 68, 20.0, 1],
#        ['Oregon', 4.9, 159, 67, 29.3, 1],
#        ['Pennsylvania', 6.3, 106, 72, 14.9, 1],
#        ['Rhode Island', 3.4, 174, 87, 8.3, 1],
#        ['South Carolina', 14.4, 279, 48, 22.5, 0],
#        ['South Dakota', 3.8, 86, 45, 12.8, 2],
#        ['Tennessee', 13.2, 188, 59, 26.9, 0],
#        ['Texas', 12.7, 201, 80, 25.5, 3],
#        ['Utah', 3.2, 120, 80, 22.9, 1],
#        ['Vermont', 2.2, 48, 32, 11.2, 2],
#        ['Virginia', 8.5, 156, 63, 20.7, 1],
#        ['Washington', 4.0, 145, 73, 26.2, 1],
#        ['West Virginia', 5.7, 81, 39, 9.3, 2],
#        ['Wisconsin', 2.6, 53, 66, 10.8, 1],
#        ['Wyoming', 6.8, 161, 60, 15.6, 1]], dtype=object)

# %%
stscaler = StandardScaler()
X=stscaler.fit_transform(array_DBSCAN)
X
# Out:
# array([[ 1.25517927, -0.52619514, -0.00345116, -1.48365074],
#        [ 0.51301858, -1.22406668,  2.50942392, -1.48365074],
#        [ 0.07236067,  1.00912225,  1.05346626,  1.4446073 ],
#        [ 0.23470832, -1.08449238, -0.18679398, -0.50756473],
#        [ 0.28109336,  1.77678094,  2.08881393,  1.4446073 ],
#        [ 0.02597562,  0.86954794,  1.88390137,  1.4446073 ],
#        [-1.04088037,  0.79976079, -1.09272319, -0.50756473],
#        [-0.43787481,  0.45082502, -0.58583422, -0.50756473],
#        [ 1.76541475,  1.00912225,  1.1505301 ,  1.4446073 ],
#        [ 2.22926518, -0.38662083,  0.49265293, -1.48365074],
#        [-0.57702994,  1.21848371, -0.11129987, -0.50756473],
#        [-1.20322802, -0.80534376, -0.75839217,  0.46852129],
#        [ 0.60578867,  1.21848371,  0.29852525,  1.4446073 ],
#        [-0.13637203, -0.03768506, -0.0250209 , -0.50756473],
#        [-1.29599811, -0.5959823 , -1.07115345,  0.46852129],
#        [-0.41468229,  0.03210209, -0.34856705, -0.50756473],
#        [ 0.44344101, -0.94491807, -0.53190987, -0.50756473],
#        [ 1.76541475,  0.03210209,  0.10439756, -1.48365074],
#        [-1.31919063, -1.01470522, -1.44862395,  0.46852129],
#        [ 0.81452136,  0.10188925,  0.70835037,  1.4446073 ],
#        [-0.78576263,  1.35805802, -0.53190987, -0.50756473],
#        [ 1.00006153,  0.59039932,  1.49564599,  1.4446073 ],
#        [-1.1800355 ,  0.03210209, -0.68289807, -0.50756473],
#        [ 1.9277624 , -1.5032153 , -0.44563089, -1.48365074],
#        [ 0.28109336,  0.31125071,  0.75148985,  1.4446073 ],
#        [-0.41468229, -0.87513091, -0.521125  ,  0.46852129],
#        [-0.80895515, -0.24704653, -0.51034012,  0.46852129],
#        [ 1.02325405,  1.0789094 ,  2.671197  ,  1.4446073 ],
#        [-1.31919063, -0.66576945, -1.26528114,  0.46852129],
#        [-0.08998698,  1.63720664, -0.26228808, -0.50756473],
#        [ 0.83771388,  0.31125071,  1.17209984,  1.4446073 ],
#        [ 0.76813632,  1.42784517,  0.52500755,  1.4446073 ],
#        [ 1.20879423, -1.43342815, -0.55347961, -1.48365074],
#        [-1.62069341, -1.5032153 , -1.50254831,  0.46852129],
#        [-0.11317951,  0.66018648,  0.01811858, -0.50756473],
#        [-0.27552716,  0.1716764 , -0.13286962, -0.50756473],
#        [-0.66980002,  0.10188925,  0.87012344, -0.50756473],
#        [-0.34510472,  0.45082502, -0.68289807, -0.50756473],
#        [-1.01768785,  1.49763233, -1.39469959, -0.50756473],
#        [ 1.53348953, -1.22406668,  0.13675217, -1.48365074],
#        [-0.92491776, -1.43342815, -0.90938037,  0.46852129],
#        [ 1.25517927, -0.45640799,  0.61128652, -1.48365074],
#        [ 1.13921666,  1.00912225,  0.46029832,  1.4446073 ],
#        [-1.06407289,  1.00912225,  0.17989166, -0.50756473],
#        [-1.29599811, -2.34066115, -1.08193832,  0.46852129],
#        [ 0.16513075, -0.17725937, -0.05737552, -0.50756473],
#        [-0.87853272,  0.52061217,  0.53579242, -0.50756473],
#        [-0.48425985, -1.85215107, -1.28685088,  0.46852129],
#        [-1.20322802,  0.03210209, -1.1250778 , -0.50756473],
#        [-0.22914211, -0.38662083, -0.60740397, -0.50756473]])

# %%
dbscan = DBSCAN(eps=1.2,min_samples=4)
dbscan.fit(X)
# Out:
# DBSCAN(eps=1.2, min_samples=4)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([ 0, -1,  1,  2,  1,  1,  2,  2,  1,  0,  2,  2,  1,  2,  2,  2,  2,
#         0,  2,  1,  2,  1,  2,  0,  1,  2,  2, -1,  2,  2,  1,  1,  0,  2,
#         2,  2,  2,  2,  2,  0,  2,  0,  1,  2,  2,  2,  2,  2,  2,  2],
#       dtype=int64)

# %%
df['cluster']=pd.DataFrame(dbscan.labels_)

# %%
df
# Out:
#     Murder  UrbanPop  Rape  h_clusterid  cluster
# 0     13.2        58  21.2            0        0
# 1     10.0        48  44.5            0       -1
# 2      8.1        80  31.0            3        1
# 3      8.8        50  19.5            1        2
# 4      9.0        91  40.6            3        1
# 5      7.9        78  38.7            3        1
# 6      3.3        77  11.1            1        2
# 7      5.9        72  15.8            1        2
# 8     15.4        80  31.9            3        1
# 9     17.4        60  25.8            0        0
# 10     5.3        83  20.2            1        2
# 11     2.6        54  14.2            2        2
# 12    10.4        83  24.0            3        1
# 13     7.2        65  21.0            1        2
# 14     2.2        57  11.3            2        2
# 15     6.0        66  18.0            1        2
# 16     9.7        52  16.3            1        2
# 17    15.4        66  22.2            0        0
# 18     2.1        51   7.8            2        2
# 19    11.3        67  27.8            3        1
# 20     4.4        85  16.3            1        2
# 21    12.1        74  35.1            3        1
# 22     2.7        66  14.9            1        2
# 23    16.1        44  17.1            0        0
# 24     9.0        70  28.2            3        1
# 25     6.0        53  16.4            2        2
# 26     4.3        62  16.5            2        2
# 27    12.2        81  46.0            3       -1
# 28     2.1        56   9.5            2        2
# 29     7.4        89  18.8            1        2
# 30    11.4        70  32.1            3        1
# 31    11.1        86  26.1            3        1
# 32    13.0        45  16.1            0        0
# 33     0.8        44   7.3            2        2
# 34     7.3        75  21.4            1        2
# 35     6.6        68  20.0            1        2
# 36     4.9        67  29.3            1        2
# 37     6.3        72  14.9            1        2
# 38     3.4        87   8.3            1        2
# 39    14.4        48  22.5            0        0
# 40     3.8        45  12.8            2        2
# 41    13.2        59  26.9            0        0
# 42    12.7        80  25.5            3        1
# 43     3.2        80  22.9            1        2
# 44     2.2        32  11.2            2        2
# 45     8.5        63  20.7            1        2
# 46     4.0        73  26.2            1        2
# 47     5.7        39   9.3            2        2
# 48     2.6        66  10.8            1        2
# 49     6.8        60  15.6            1        2

# %%
df['cluster'].value_counts()
# Out:
#  2    30
#  1    11
#  0     7
# -1     2
# Name: cluster, dtype: int64

# %%
#To find the percentage of noise points
(len(df[df['cluster']==-1])/len(df))*100
# Out:
# 4.0

# %%
from sklearn import metrics
X=metrics.silhouette_score(X,dbscan.labels_)
X
# Out:
# 0.4251562001046779

# %%
def dbscan(X,eps,min_samples):
    ss=StandardScaler()
    db=DBSCAN(eps=eps,min_samples=min_samples)
    db.fit(X)
    y_pred=db.fit_predict(X)
    plt.scatter(x[:,1],x[:,1],c=y_pred,edgecolors='red')
    plt.scatter(x[:,2],x[:,1],c=y_pred,edgecolors='green')
    plt.scatter(x[:,3],x[:,1],c=y_pred)
    plt.title('DBSCAN')

# %%
dbscan(scaled_df,0.3,7)
