# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import Holt
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
cocacola=pd .read_excel("C:\\Users\\lenovo\\Downloads\\CocaCola_Sales_Rawdata.xlsx")

# %%
cocacola
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# 37   Q2_95  4936.000000
# 38   Q3_95  4895.000000
# 39   Q4_95  4333.000000
# 40   Q1_96  4194.000000
# 41   Q2_96  5253.000000

# %% [markdown]
# # plotting the data

# %%
cocacola.Sales.plot()
# Out:
# <AxesSubplot:>

# %%
len(cocacola)
# Out:
# 42

# %% [markdown]
# # Spliring train and test data

# %%
train=cocacola.head(30)
test=cocacola.tail(12)

# %%
train
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000

# %%
test
# Out:
#    Quarter   Sales
# 30   Q3_93  3629.0
# 31   Q4_93  3373.0
# 32   Q1_94  3352.0
# 33   Q2_94  4342.0
# 34   Q3_94  4461.0
# 35   Q4_94  4017.0
# 36   Q1_95  3854.0
# 37   Q2_95  4936.0
# 38   Q3_95  4895.0
# 39   Q4_95  4333.0
# 40   Q1_96  4194.0
# 41   Q2_96  5253.0

# %% [markdown]
# # ploting the moving average

# %%
a=range(2,12,2)
plt.figure(figsize=(24,7))
cocacola.Sales.plot(label="org")
for i in a:
    cocacola["Sales"].rolling(i).mean().plot(label=str(i))
plt.legend(loc='best')

# %% [markdown]
# # ploting moving average

# %%
decompose_ts_add=seasonal_decompose(cocacola.Sales,period=4)
decompose_ts_add.plot()
plt.show()

# %% [markdown]
# # ACF & PACF plots

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(cocacola.Sales,lags=4)
tsa_plots.plot_pacf(cocacola.Sales,lags=4)
plt.show()

# %% [markdown]
# # Evaluation Metric MAPE

# %%
def MAPE(pred,org):
    temp=np.abs((pred-org)/org)*100
    return np.mean(temp)

# %%
weights=np.array([0.1,0.2,0.3,0.4])

# %% [markdown]
# # Weighted moving average

# %%
df=pd.DataFrame()
df['Sales']=cocacola.Sales
df['WMA']=df['Sales'].rolling(4).apply(lambda x:np.sum(weights*x))
df
# Out:
#           Sales          WMA
# 0   1734.827000          NaN
# 1   2244.960999          NaN
# 2   2533.804993          NaN
# 3   2154.962997  2244.601596
# 4   1547.818996  1996.873596
# 5   2104.411995  1990.483596
# 6   2014.362999  1962.128897
# 7   1991.746998  1976.671997
# 8   1869.049999  1958.457898
# 9   2313.631996  2085.953498
# 10  2128.320000  2118.402298
# 11  2026.828999  2098.858998
# 12  1910.603996  2029.317498
# 13  2331.164993  2123.844996
# 14  2206.549995  2166.773195
# 15  2173.967995  2188.845595
# 16  2148.278000  2185.928097
# 17  2739.307999  2395.655198
# 18  2792.753998  2585.946398
# 19  2556.009995  2622.919597
# 20  2480.973999  2591.674197
# 21  3039.522995  2750.578796
# 22  3172.115997  2932.499097
# 23  2879.000999  2959.237198
# 24  2772.000000  2910.875799
# 25  3550.000000  3144.611800
# 26  3508.000000  3310.500100
# 27  3243.859993  3337.143997
# 28  3056.000000  3252.157998
# 29  3899.000000  3475.971999
# 30  3629.000000  3556.885999
# 31  3373.000000  3523.300000
# 32  3352.000000  3468.400000
# 33  4342.000000  3779.900000
# 34  4461.000000  4094.700000
# 35  4017.000000  4148.700000
# 36  3854.000000  4073.100000
# 37  4936.000000  4380.100000
# 38  4895.000000  4611.300000
# 39  4333.000000  4574.300000
# 40  4194.000000  4450.100000
# 41  5253.000000  4715.500000

# %% [markdown]
# # plotting weighted moving average

# %%
df.Sales.plot(kind='line')
df.WMA.plot(kind='line')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# # simple Exponential Method

# %%
ses_model=SimpleExpSmoothing(train['Sales']).fit(smoothing_level=0.2)
pred_ses=ses_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_ses,test.Sales)
# Out:
# 22.04676239130592

# %% [markdown]
# # plotting for predictions for test data

# %%
plt.plot(pred_ses)
plt.plot(test.Sales)

# %% [markdown]
# # whole data

# %%
plt.plot(ses_model.predict(start=cocacola.index[0],end=cocacola.index[-1]))
plt.plot(cocacola.Sales)

# %% [markdown]
# # find the best smoothing level value

# %%
acc_ses={}
for i in range(101):
    ses_model=SimpleExpSmoothing(train["Sales"]).fit(smoothing_level=i/100)
    pred_ses=ses_model.predict(start=test.index[0],end=test.index[-1])
    acc_ses[MAPE(pred_ses,test.Sales)]=i
    
print('{}:{}'.format(acc_ses[min(acc_ses.keys())],min(acc_ses.keys())))
# Out:
# 100:12.53674608511905

# %% [markdown]
# # Build a model with 1 as the smooting level values

# %%
ses_model=SimpleExpSmoothing(train["Sales"]).fit(smoothing_level=1)
pred_ses=ses_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_ses,test.Sales)
# Out:
# 12.53674608511905

# %% [markdown]
# # plotting the predictions on test data

# %%
plt.plot(pred_ses)
plt.plot(test.Sales)

# %% [markdown]
# # Whole data

# %%
plt.plot(ses_model.predict(start=cocacola.index[0],end=cocacola.index[-1]))
plt.plot(cocacola.Sales)

# %% [markdown]
# # Build a model with holt method

# %%
holt_model=Holt(train["Sales"]).fit(smoothing_level=0.8,smoothing_slope=0.3)
pred_holt=holt_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_holt,test.Sales)
# Out:
# 14.949345451991237

# %% [markdown]
# # plotting the prediction on test data

# %%
plt.plot(pred_holt)
plt.plot(test.Sales)

# %% [markdown]
# # Whole data

# %%
plt.plot(holt_model.predict(start=cocacola.index[0],end=cocacola.index[-1]))
plt.plot(cocacola.Sales)

# %% [markdown]
# # Find the best hyper parameters

# %%
accuracy={}
for i in range(0,101):
    for j in range(0,101):
        holt_model=Holt(train["Sales"]).fit(smoothing_level=i/100,smoothing_slope=j/100)
        pred_holt=holt_model.predict(start=test.index[0],end=test.index[-1])
        accuracy[MAPE(pred_holt,test.Sales)]=(i,j)

# %%
accuracy[min(accuracy.keys())]
# Out:
# (18, 77)

# %%
min(accuracy.keys())
# Out:
# 8.341825896458998

# %% [markdown]
# # Build a model with smoothing level=0.18 & smoothing sloe=0.77

# %%
holt_model=Holt(train["Sales"]).fit(smoothing_level=0.18,smoothing_slope=0.77)
pred_holt=holt_model.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_holt,test.Sales)
# Out:
# 8.341825896458998

# %% [markdown]
# # plotting the predictions on the test data

# %%
plt.plot(pred_holt)
plt.plot(test.Sales)

# %% [markdown]
# # Whole Data

# %%
plt.plot(holt_model.predict(start=cocacola.index[0],end=cocacola.index[-1]))
plt.plot(cocacola.Sales)

# %% [markdown]
# # Build a model using holt winters method

# %% [markdown]
# # from the moving average plotted is earliers, it can be seen that the best seasonal period value is 4

# %%
hw_add_add = ExponentialSmoothing(train["Sales"],seasonal='add',seasonal_periods=4).fit()
pred_hw_add=hw_add_add.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_hw_add,test.Sales)
# Out:
# 13.792793718315473

# %% [markdown]
# # ploting the predictions in the test data

# %%
plt.plot(pred_hw_add)
plt.plot(test.Sales)

# %% [markdown]
# # Whole data

# %%
plt.plot(hw_add_add.predict(start=cocacola.index[0],end=cocacola.index[-1]))
plt.plot(cocacola.Sales)

# %% [markdown]
# # Build a model using holt winters method

# %% [markdown]
# # from the moving average plotted earlier,it can be seen that the best seasonal periods values is 4

# %%
hw_add_add=ExponentialSmoothing(train["Sales"],seasonal='mul',trend='mul',seasonal_periods=4).fit()
pred_hw=hw_add_add.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_hw_add,test.Sales)
# Out:
# 13.792793718315473

# %% [markdown]
# # find the best hyperparameter

# %%
params=['add','mul']
acc_hw={}
for i in params:
    for j in params:
        hw=ExponentialSmoothing(train["Sales"],seasonal=i,trend=j,seasonal_periods=12).fit()
        pred_hw=hw.predict(start=test.index[0],end=test.index[-1])
        acc_hw[MAPE(pred_hw,test.Sales)]=(i,j)

# %%
acc_hw[min(acc_hw.keys())]
# Out:
# ('mul', 'mul')

# %%
min(acc_hw.keys())
# Out:
# 3.323386895375649

# %% [markdown]
# # Build a model with seasonal & trend to be multiplicative

# %%
hw=ExponentialSmoothing(train["Sales"],seasonal='mul',trend='mul',seasonal_periods=4).fit()
pred_hw=hw.predict(start=test.index[0],end=test.index[-1])
MAPE(pred_hw,test.Sales)
# Out:
# 2.767571919763732

# %% [markdown]
# # plotting the prediction on the test data

# %%
plt.plot(pred_hw)
plt.plot(test.Sales)

# %% [markdown]
# # Whole data

# %%
plt.plot(ses_model.predict(start=cocacola.index[0],end=cocacola.index[-1]))
plt.plot(cocacola.Sales)

# %% [markdown]
# # conclusions

# %% [markdown]
# simple Exponential Smoothing = The best smoothing level value was found to be 1 the model built this value has an rms error value of 12.53

# %% [markdown]
# Holt's Model=The Best smoothing level value was found to be 0.18 & smoothing slope value is 0.77 the model built whit these parameters have an rms error value of 8.34

# %% [markdown]
# Holt-winter Method = The plitting both seasonal & trend to be multiplicative give the best results.the model built with these parameters gives an rms erroe of 2.75

# %% [markdown]
# so select the model is Holt Winters Model
